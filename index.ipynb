# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Explore unknown JSON schemas
# * Access and manipulate data inside a JSON file
# * Convert JSON to alternative data formats

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file disease_data.json.

# %%
#Your code here 
import json

f = open('disease_data.json')
data = json.load(f)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
for key in data:
    print(key,type(data))
# Out:
# meta <class 'dict'>
# data <class 'dict'>

# %%
for key in data['meta']:
    print(key,type(data['meta'][key]))
# Out:
# view <class 'dict'>

# %%
type(data['meta']['view'])
# Out:
# dict

# %%
data['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'attribution', 'attributionLink', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'licenseId', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'columns', 'grants', 'license', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
for key in data['meta']['view']:
    print(key,type(data['meta']['view'][key]))
# Out:
# id <class 'str'>
# name <class 'str'>
# attribution <class 'str'>
# attributionLink <class 'str'>
# averageRating <class 'int'>
# category <class 'str'>
# createdAt <class 'int'>
# description <class 'str'>
# displayType <class 'str'>
# downloadCount <class 'int'>
# hideFromCatalog <class 'bool'>
# hideFromDataJson <class 'bool'>
# indexUpdatedAt <class 'int'>
# licenseId <class 'str'>
# newBackend <class 'bool'>
# numberOfComments <class 'int'>
# oid <class 'int'>
# provenance <class 'str'>
# publicationAppendEnabled <class 'bool'>
# publicationDate <class 'int'>
# publicationGroup <class 'int'>
# publicationStage <class 'str'>
# rowClass <class 'str'>
# rowsUpdatedAt <class 'int'>
# rowsUpdatedBy <class 'str'>
# tableId <class 'int'>
# totalTimesRated <class 'int'>
# viewCount <class 'int'>
# viewLastModified <class 'int'>
# viewType <class 'str'>
# columns <class 'list'>
# grants <class 'list'>
# license <class 'dict'>
# metadata <class 'dict'>
# owner <class 'dict'>
# query <class 'dict'>
# rights <class 'list'>
# tableAuthor <class 'dict'>
# tags <class 'list'>
# flags <class 'list'>

# %%
type(data['data'])
# Out:
# list

# %%
len(data['data'])
# Out:
# 60266

# %%
data['data'][0]
# Out:
# [1,
#  'FF49C41F-CE8D-46C4-9164-653B1227CF6F',
#  1,
#  1527194521,
#  '959778',
#  1527194521,
#  '959778',
#  None,
#  '2016',
#  '2016',
#  'US',
#  'United States',
#  'BRFSS',
#  'Alcohol',
#  'Binge drinking prevalence among adults aged >= 18 years',
#  None,
#  '%',
#  'Crude Prevalence',
#  '16.9',
#  '16.9',
#  '*',
#  '50 States + DC: US Median',
#  '16',
#  '18',
#  'Overall',
#  'Overall',
#  None,
#  None,
#  None,
#  None,
#  [None, None, None, None, None],
#  None,
#  '59',
#  'ALC',
#  'ALC2_2',
#  'CRDPREV',
#  'OVERALL',
#  'OVR',
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
#Your code here
import pandas as pd

df = pd.DataFrame(data['data'])
df.columns = [item['name'] for item in data['meta']['view']['columns']]
df.set_index('sid',inplace=True)
df.head()
# Out:
#                                        id  position  created_at created_meta  \
# sid
# 1    FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521       959778
# 2    F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521       959778
# 3    65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521       959778
# 4    0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521       959778
# 5    D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521       959778
#
#      updated_at updated_meta  meta YearStart YearEnd LocationAbbr  \
# sid
# 1    1527194521       959778  None      2016    2016           US
# 2    1527194521       959778  None      2016    2016           AL
# 3    1527194521       959778  None      2016    2016           AK
# 4    1527194521       959778  None      2016    2016           AZ
# 5    1527194521       959778  None      2016    2016           AR
#
#            ...        LocationID TopicID QuestionID DataValueTypeID  \
# sid        ...
# 1          ...                59     ALC     ALC2_2         CRDPREV
# 2          ...                01     ALC     ALC2_2         CRDPREV
# 3          ...                02     ALC     ALC2_2         CRDPREV
# 4          ...                04     ALC     ALC2_2         CRDPREV
# 5          ...                05     ALC     ALC2_2         CRDPREV
#
#     StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# sid
# 1                     OVERALL               OVR                      None
# 2                     OVERALL               OVR                      None
# 3                     OVERALL               OVR                      None
# 4                     OVERALL               OVR                      None
# 5                     OVERALL               OVR                      None
#
#     StratificationID2 StratificationCategoryID3 StratificationID3
# sid
# 1                None                      None              None
# 2                None                      None              None
# 3                None                      None              None
# 4                None                      None              None
# 5                None                      None              None
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %%
df.Question.head()
# Out:
# sid
# 1    Binge drinking prevalence among adults aged >=...
# 2    Binge drinking prevalence among adults aged >=...
# 3    Binge drinking prevalence among adults aged >=...
# 4    Binge drinking prevalence among adults aged >=...
# 5    Binge drinking prevalence among adults aged >=...
# Name: Question, dtype: object

# %%
df[df.Topic == 'Asthma'].Question.value_counts(normalize= True).cumsum()[:10]
# Out:
# Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma    0.186096
# Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma       0.372193
# Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma       0.558289
# Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with asthma    0.744385
# Current asthma prevalence among adults aged >= 18 years                                    0.930481
# Asthma prevalence among women aged 18-44 years                                             1.000000
# Name: Question, dtype: float64

# %%
cols = ['LocationAbbr', 'LocationDesc', 'DataSource','Topic', 'Question', 'YearStart', 'YearEnd', 'DataValue']
view = df[df.Question == 'Current asthma prevalence among adults aged >= 18 years'][cols]
view.head()
# Out:
#      LocationAbbr LocationDesc DataSource   Topic  \
# sid
# 4726           IL     Illinois      BRFSS  Asthma
# 5530           IN      Indiana      BRFSS  Asthma
# 5633           IA         Iowa      BRFSS  Asthma
# 6778           KS       Kansas      BRFSS  Asthma
# 7035           KY     Kentucky      BRFSS  Asthma
#
#                                                Question YearStart YearEnd  \
# sid
# 4726  Current asthma prevalence among adults aged >=...      2016    2016
# 5530  Current asthma prevalence among adults aged >=...      2016    2016
# 5633  Current asthma prevalence among adults aged >=...      2016    2016
# 6778  Current asthma prevalence among adults aged >=...      2016    2016
# 7035  Current asthma prevalence among adults aged >=...      2016    2016
#
#      DataValue
# sid
# 4726       6.5
# 5530       6.7
# 5633       5.6
# 6778       6.1
# 7035       6.9

# %%
view.sort_values(by = 'LocationAbbr').head()
# Out:
#       LocationAbbr LocationDesc DataSource   Topic  \
# sid
# 9794            AK       Alaska      BRFSS  Asthma
# 10010           AK       Alaska      BRFSS  Asthma
# 9425            AK       Alaska      BRFSS  Asthma
# 9956            AK       Alaska      BRFSS  Asthma
# 9902            AK       Alaska      BRFSS  Asthma
#
#                                                 Question YearStart YearEnd  \
# sid
# 9794   Current asthma prevalence among adults aged >=...      2016    2016
# 10010  Current asthma prevalence among adults aged >=...      2016    2016
# 9425   Current asthma prevalence among adults aged >=...      2016    2016
# 9956   Current asthma prevalence among adults aged >=...      2016    2016
# 9902   Current asthma prevalence among adults aged >=...      2016    2016
#
#       DataValue
# sid
# 9794       None
# 10010      10.3
# 9425          9
# 9956       None
# 9902       None

# %%
view.groupby('LocationAbbr').head()
# Out:
#      LocationAbbr          LocationDesc DataSource   Topic  \
# sid
# 4726           IL              Illinois      BRFSS  Asthma
# 5530           IN               Indiana      BRFSS  Asthma
# 5633           IA                  Iowa      BRFSS  Asthma
# 6778           KS                Kansas      BRFSS  Asthma
# 7035           KY              Kentucky      BRFSS  Asthma
# 7337           LA             Louisiana      BRFSS  Asthma
# 7428           ME                 Maine      BRFSS  Asthma
# 7499           MD              Maryland      BRFSS  Asthma
# 7966           VT               Vermont      BRFSS  Asthma
# 8114           VA              Virginia      BRFSS  Asthma
# 8135           FL               Florida      BRFSS  Asthma
# 8234           GU                  Guam      BRFSS  Asthma
# 9137           HI                Hawaii      BRFSS  Asthma
# 9217           ID                 Idaho      BRFSS  Asthma
# 9368           US         United States      BRFSS  Asthma
# 9369           AL               Alabama      BRFSS  Asthma
# 9370           AK                Alaska      BRFSS  Asthma
# 9371           AZ               Arizona      BRFSS  Asthma
# 9372           AR              Arkansas      BRFSS  Asthma
# 9373           CA            California      BRFSS  Asthma
# 9374           CO              Colorado      BRFSS  Asthma
# 9375           CT           Connecticut      BRFSS  Asthma
# 9376           DE              Delaware      BRFSS  Asthma
# 9377           DC  District of Columbia      BRFSS  Asthma
# 9378           FL               Florida      BRFSS  Asthma
# 9379           GA               Georgia      BRFSS  Asthma
# 9380           HI                Hawaii      BRFSS  Asthma
# 9381           ID                 Idaho      BRFSS  Asthma
# 9382           IL              Illinois      BRFSS  Asthma
# 9383           IN               Indiana      BRFSS  Asthma
# ...           ...                   ...        ...     ...
# 9599           MN             Minnesota      BRFSS  Asthma
# 9600           MS           Mississippi      BRFSS  Asthma
# 9601           MO              Missouri      BRFSS  Asthma
# 9602           MT               Montana      BRFSS  Asthma
# 9603           NE              Nebraska      BRFSS  Asthma
# 9604           NV                Nevada      BRFSS  Asthma
# 9605           NH         New Hampshire      BRFSS  Asthma
# 9606           NJ            New Jersey      BRFSS  Asthma
# 9607           NM            New Mexico      BRFSS  Asthma
# 9608           NY              New York      BRFSS  Asthma
# 9609           NC        North Carolina      BRFSS  Asthma
# 9610           ND          North Dakota      BRFSS  Asthma
# 9611           OH                  Ohio      BRFSS  Asthma
# 9612           OK              Oklahoma      BRFSS  Asthma
# 9613           OR                Oregon      BRFSS  Asthma
# 9614           PA          Pennsylvania      BRFSS  Asthma
# 9615           RI          Rhode Island      BRFSS  Asthma
# 9616           SC        South Carolina      BRFSS  Asthma
# 9617           SD          South Dakota      BRFSS  Asthma
# 9618           TN             Tennessee      BRFSS  Asthma
# 9619           TX                 Texas      BRFSS  Asthma
# 9620           UT                  Utah      BRFSS  Asthma
# 9621           VT               Vermont      BRFSS  Asthma
# 9622           VA              Virginia      BRFSS  Asthma
# 9623           WA            Washington      BRFSS  Asthma
# 9624           WV         West Virginia      BRFSS  Asthma
# 9625           WI             Wisconsin      BRFSS  Asthma
# 9626           WY               Wyoming      BRFSS  Asthma
# 9628           PR           Puerto Rico      BRFSS  Asthma
# 9629           VI        Virgin Islands      BRFSS  Asthma
#
#                                                Question YearStart YearEnd  \
# sid
# 4726  Current asthma prevalence among adults aged >=...      2016    2016
# 5530  Current asthma prevalence among adults aged >=...      2016    2016
# 5633  Current asthma prevalence among adults aged >=...      2016    2016
# 6778  Current asthma prevalence among adults aged >=...      2016    2016
# 7035  Current asthma prevalence among adults aged >=...      2016    2016
# 7337  Current asthma prevalence among adults aged >=...      2016    2016
# 7428  Current asthma prevalence among adults aged >=...      2016    2016
# 7499  Current asthma prevalence among adults aged >=...      2016    2016
# 7966  Current asthma prevalence among adults aged >=...      2016    2016
# 8114  Current asthma prevalence among adults aged >=...      2016    2016
# 8135  Current asthma prevalence among adults aged >=...      2016    2016
# 8234  Current asthma prevalence among adults aged >=...      2016    2016
# 9137  Current asthma prevalence among adults aged >=...      2016    2016
# 9217  Current asthma prevalence among adults aged >=...      2016    2016
# 9368  Current asthma prevalence among adults aged >=...      2016    2016
# 9369  Current asthma prevalence among adults aged >=...      2016    2016
# 9370  Current asthma prevalence among adults aged >=...      2016    2016
# 9371  Current asthma prevalence among adults aged >=...      2016    2016
# 9372  Current asthma prevalence among adults aged >=...      2016    2016
# 9373  Current asthma prevalence among adults aged >=...      2016    2016
# 9374  Current asthma prevalence among adults aged >=...      2016    2016
# 9375  Current asthma prevalence among adults aged >=...      2016    2016
# 9376  Current asthma prevalence among adults aged >=...      2016    2016
# 9377  Current asthma prevalence among adults aged >=...      2016    2016
# 9378  Current asthma prevalence among adults aged >=...      2016    2016
# 9379  Current asthma prevalence among adults aged >=...      2016    2016
# 9380  Current asthma prevalence among adults aged >=...      2016    2016
# 9381  Current asthma prevalence among adults aged >=...      2016    2016
# 9382  Current asthma prevalence among adults aged >=...      2016    2016
# 9383  Current asthma prevalence among adults aged >=...      2016    2016
# ...                                                 ...       ...     ...
# 9599  Current asthma prevalence among adults aged >=...      2016    2016
# 9600  Current asthma prevalence among adults aged >=...      2016    2016
# 9601  Current asthma prevalence among adults aged >=...      2016    2016
# 9602  Current asthma prevalence among adults aged >=...      2016    2016
# 9603  Current asthma prevalence among adults aged >=...      2016    2016
# 9604  Current asthma prevalence among adults aged >=...      2016    2016
# 9605  Current asthma prevalence among adults aged >=...      2016    2016
# 9606  Current asthma prevalence among adults aged >=...      2016    2016
# 9607  Current asthma prevalence among adults aged >=...      2016    2016
# 9608  Current asthma prevalence among adults aged >=...      2016    2016
# 9609  Current asthma prevalence among adults aged >=...      2016    2016
# 9610  Current asthma prevalence among adults aged >=...      2016    2016
# 9611  Current asthma prevalence among adults aged >=...      2016    2016
# 9612  Current asthma prevalence among adults aged >=...      2016    2016
# 9613  Current asthma prevalence among adults aged >=...      2016    2016
# 9614  Current asthma prevalence among adults aged >=...      2016    2016
# 9615  Current asthma prevalence among adults aged >=...      2016    2016
# 9616  Current asthma prevalence among adults aged >=...      2016    2016
# 9617  Current asthma prevalence among adults aged >=...      2016    2016
# 9618  Current asthma prevalence among adults aged >=...      2016    2016
# 9619  Current asthma prevalence among adults aged >=...      2016    2016
# 9620  Current asthma prevalence among adults aged >=...      2016    2016
# 9621  Current asthma prevalence among adults aged >=...      2016    2016
# 9622  Current asthma prevalence among adults aged >=...      2016    2016
# 9623  Current asthma prevalence among adults aged >=...      2016    2016
# 9624  Current asthma prevalence among adults aged >=...      2016    2016
# 9625  Current asthma prevalence among adults aged >=...      2016    2016
# 9626  Current asthma prevalence among adults aged >=...      2016    2016
# 9628  Current asthma prevalence among adults aged >=...      2016    2016
# 9629  Current asthma prevalence among adults aged >=...      2016    2016
#
#      DataValue
# sid
# 4726       6.5
# 5530       6.7
# 5633       5.6
# 6778       6.1
# 7035       6.9
# 7337       5.4
# 7428       9.4
# 7499       7.2
# 7966       7.2
# 8114       5.3
# 8135       8.2
# 8234       7.5
# 9137       7.5
# 9217       6.9
# 9368       9.3
# 9369       9.7
# 9370       8.8
# 9371       9.4
# 9372       8.5
# 9373       7.8
# 9374       8.8
# 9375      10.5
# 9376       8.5
# 9377       9.8
# 9378       6.7
# 9379       8.5
# 9380      10.7
# 9381       9.3
# 9382       8.9
# 9383      10.2
# ...        ...
# 9599       9.8
# 9600      10.4
# 9601      12.5
# 9602      10.5
# 9603      10.4
# 9604      10.9
# 9605      15.8
# 9606      10.2
# 9607      14.4
# 9608      11.5
# 9609      10.6
# 9610      10.7
# 9611      11.3
# 9612      12.2
# 9613      13.2
# 9614        14
# 9615      13.9
# 9616      11.1
# 9617       7.2
# 9618      14.3
# 9619      10.1
# 9620      10.1
# 9621        13
# 9622      11.6
# 9623      12.5
# 9624      14.8
# 9625      10.3
# 9626      12.6
# 9628      12.3
# 9629       8.3
#
# [275 rows x 8 columns]

# %%
df.StratificationCategoryID1.value_counts(normalize=True)
# Out:
# RACE       0.631534
# GENDER     0.231673
# OVERALL    0.136794
# Name: StratificationCategoryID1, dtype: float64

# %%
view = df[(df.Question == 'Current asthma prevalence among adults aged >= 18 years')
         & (df.StratificationCategoryID1 == 'OVERALL')& (df.DataValueTypeID == 'CRDPREV')]
view = view.sort_values(by='LocationAbbr')
view.head()
# Out:
#                                         id  position  created_at created_meta  \
# sid
# 9370  5D6EDDA9-B241-4498-A262-ED20AB78C44C      9370  1527194523       959778
# 9369  6BEC61D0-E04B-44BA-8170-F7D6A4C40A09      9369  1527194523       959778
# 9372  68F151CE-3084-402C-B672-78A43FBDE287      9372  1527194523       959778
# 9371  5FCE0D49-11FD-4545-B9E7-14F503123105      9371  1527194523       959778
# 9373  D3F00ED2-A069-4E40-B42B-5A2528A91B6F      9373  1527194523       959778
#
#       updated_at updated_meta  meta YearStart YearEnd LocationAbbr  \
# sid
# 9370  1527194523       959778  None      2016    2016           AK
# 9369  1527194523       959778  None      2016    2016           AL
# 9372  1527194523       959778  None      2016    2016           AR
# 9371  1527194523       959778  None      2016    2016           AZ
# 9373  1527194523       959778  None      2016    2016           CA
#
#             ...        LocationID TopicID QuestionID DataValueTypeID  \
# sid         ...
# 9370        ...                02     AST     AST1_1         CRDPREV
# 9369        ...                01     AST     AST1_1         CRDPREV
# 9372        ...                05     AST     AST1_1         CRDPREV
# 9371        ...                04     AST     AST1_1         CRDPREV
# 9373        ...                06     AST     AST1_1         CRDPREV
#
#      StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# sid
# 9370                   OVERALL               OVR                      None
# 9369                   OVERALL               OVR                      None
# 9372                   OVERALL               OVR                      None
# 9371                   OVERALL               OVR                      None
# 9373                   OVERALL               OVR                      None
#
#      StratificationID2 StratificationCategoryID3 StratificationID3
# sid
# 9370              None                      None              None
# 9369              None                      None              None
# 9372              None                      None              None
# 9371              None                      None              None
# 9373              None                      None              None
#
# [5 rows x 41 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
view.DataValue = view.DataValue.astype(float)
view = view.sort_values(by='DataValue')
view.set_index('LocationAbbr')['DataValue'].plot(kind='bar', figsize=(10,10))
plt.title('Asthma Rates by State 2016')
plt.ylabel('Percent 18+ with Asthma')
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %% [markdown]
# ## Level-Up!
# ## Create a function (or class) that returns an outline of the schema structure like this:
# <img src="images/outline.jpg" width="350">
#
# Rules:
# * Your outline should follow the numbering outline above (I, A, 1, a, i).
# * Your outline should be properly indented! (Four spaces or one tab per indentation level.)
# * Your function goes to at least a depth of 5 (Level-up: create a parameter so that the user can specify this)
# * If an entry is a dictionary, list its keys as the subheadings
# * After listing a key name (where applicable) include a space, a dash and the data type of the entry
# * If an entry is a dict or list put in parentheses how many items are in the entry
# * lists will not have key names for their entries (they're just indexed)
# * For subheadings of a list, state their datatypes.
# * If a dictionary or list is more then 5 items long, only show the first 5 (we want to limit our previews); make an arbitrary order choice for dictionaries. (Level-up: Parallel to above; allow user to specify number of items to preview for large subheading collections.)

# %%
# Your code here; you will probably want to define subfunctions.
def print_obj_outline(json_obj):
    return outline

# %%
outline = print_obj_outline(data)

# %%
print(outline) #Your function should produce the following output for this json object (and work for all json files!)
# Out:
# I. root - <class 'dict'> (2 items)
#     A. meta <class 'dict'> (1 items)
#         1. view <class 'dict'> (40 items)
#             a. id <class 'str'>
#             b. name <class 'str'>
#             c. attribution <class 'str'>
#             d. attributionLink <class 'str'>
#             e. averageRating <class 'int'>
#     B. data <class 'list'> (60266 items)
#         1. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         2. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         3. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         4. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         5. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files and writing a recursive generalized function for outlining a JSON file's schema!
